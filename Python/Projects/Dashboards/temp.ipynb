# %%
import numpy as np
import pandas as pd

# %%
cashier = pd.read_csv('/Users/timtism/Documents/ZaloPay/Raw data and Analysis/Raw data from Jupyter/Cashier_ZDS/Jan/Jan15_CashierLog_ZPI.csv')

# %%
cashier.head()
# Out:
#                appName  app_id      description     event_id     funnel_steps  \
# 0  Nạp Tiền Điện Thoại      61  1. Cashier Load  02.1103.000  1. Cashier Load
# 1       Thẻ Điện Thoại      12  1. Cashier Load  02.1103.000  1. Cashier Load
# 2            WITH DRAW     452  1. Cashier Load  02.1103.000  1. Cashier Load
# 3             Nạp tiền     454  1. Cashier Load  02.1103.000  1. Cashier Load
# 4             Nạp tiền     454  1. Cashier Load  02.1103.000  1. Cashier Load
#
#    key_id                                           metadata  orderamount  \
# 0     NaN  {"timeStamp":1673771641175,"os":"android","osV...       100000
# 1     NaN  {"timeStamp":1673759122247,"os":"android","osV...        10000
# 2     NaN  {"timeStamp":1673754610987,"os":"ios","osVer":...        10000
# 3     NaN  {"timeStamp":1673754627173,"os":"ios","osVer":...        17000
# 4     NaN  {"timeStamp":1673778667969,"os":"android","osV...       700000
#
# ...

# %%
import random
from datetime import datetime, timedelta

start_date = datetime(2023, 1, 6)
end_date = datetime(2023, 1, 8)
date_format = "%m/%d/%Y"

# Generate a random date within the specified range
random_date = start_date + timedelta(days=random.randint(0, (end_date - start_date).days))

# Format the random date as a string
formatted_date = random_date.strftime(date_format)

print(formatted_date)
# Out:
# 01/07/2023

# %%
cashier['date'] = (start_date +timedelta(days = random.randint(0, (end_date - start_date).days))).strftime(date_format)

# %%
cashier
# Out:
#                     appName  app_id      description     event_id  \
# 0       Nạp Tiền Điện Thoại      61  1. Cashier Load  02.1103.000
# 1            Thẻ Điện Thoại      12  1. Cashier Load  02.1103.000
# 2                 WITH DRAW     452  1. Cashier Load  02.1103.000
# 3                  Nạp tiền     454  1. Cashier Load  02.1103.000
# 4                  Nạp tiền     454  1. Cashier Load  02.1103.000
# ...                     ...     ...              ...          ...
# 443779             Nạp tiền     454  1. Cashier Load  02.1103.000
# 443780         EVN Miền Nam     429  1. Cashier Load  02.1103.000
# 443781  Nạp Tiền Điện Thoại      61  1. Cashier Load  02.1103.000
# 443782          Chuyển tiền     450  1. Cashier Load  02.1103.000
# 443783             Nạp tiền     454  1. Cashier Load  02.1103.000
#
#            funnel_steps  key_id  \
# 0       1. Cashier Load     NaN
# 1       1. Cashier Load     NaN
# 2       1. Cashier Load     NaN
# 3       1. Cashier Load     NaN
# ...
