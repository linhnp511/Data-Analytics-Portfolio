# %%
import pandas as pd
import numpy as np

# %%
survey_result_public = pd.read_csv('/Users/timtism/Documents/Github Repo/Data Analytics Portfolio/Python/Projects/StackOverFlow Developers Survey/datasets/survey_results_public.csv')
survey_result_schema = pd.read_csv('/Users/timtism/Documents/Github Repo/Data Analytics Portfolio/Python/Projects/StackOverFlow Developers Survey/datasets/survey_results_schema.csv')

# %%
survey_result_public.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
survey_result_schema.head()
# Out:
#          Column                                           Question
# 0    Respondent                               Respondent ID number
# 1  Professional         Which of the following best describes you?
# 2  ProgramHobby  Do you program as a hobby or contribute to ope...
# 3       Country            In which country do you currently live?
# 4    University  Are you currently enrolled in a formal, degree...

# %%
survey_result_public.columns.to_list()
# Out:
# ['Respondent',
#  'Professional',
#  'ProgramHobby',
#  'Country',
#  'University',
#  'EmploymentStatus',
#  'FormalEducation',
#  'MajorUndergrad',
#  'HomeRemote',
#  'CompanySize',
#  'CompanyType',
#  'YearsProgram',
#  'YearsCodedJob',
#  'YearsCodedJobPast',
#  'DeveloperType',
#  'WebDeveloperType',
#  'MobileDeveloperType',
#  'NonDeveloperType',
#  'CareerSatisfaction',
#  'JobSatisfaction',
#  'ExCoderReturn',
#  'ExCoderNotForMe',
#  'ExCoderBalance',
#  'ExCoder10Years',
#  'ExCoderBelonged',
#  'ExCoderSkills',
#  'ExCoderWillNotCode',
#  'ExCoderActive',
#  'PronounceGIF',
#  'ProblemSolving',
#  'BuildingThings',
#  'LearningNewTech',
#  'BoringDetails',
#  'JobSecurity',
#  'DiversityImportant',
#  'AnnoyingUI',
#  'FriendsDevelopers',
#  'RightWrongWay',
#  'UnderstandComputers',
#  'SeriousWork',
#  'InvestTimeTools',
#  'WorkPayCare',
#  'KinshipDevelopers',
#  'ChallengeMyself',
#  'CompetePeers',
#  'ChangeWorld',
#  'JobSeekingStatus',
#  'HoursPerWeek',
# ...

# %% [markdown]
# Question 1 - At what types of companies do developers get paid the most?

# %%
survey_result_public.CompanyType.unique()
# Out:
# array([nan, 'Privately-held limited company, not in startup mode',
#        'Publicly-traded corporation',
#        'Non-profit/non-governmental organization or private school/university',
#        'Government agency or public school/university',
#        'Pre-series A startup', 'Venture-funded startup', "I don't know",
#        'Sole proprietorship or partnership, not in startup mode',
#        'I prefer not to answer', 'State-owned company', 'Something else'],
#       dtype=object)
